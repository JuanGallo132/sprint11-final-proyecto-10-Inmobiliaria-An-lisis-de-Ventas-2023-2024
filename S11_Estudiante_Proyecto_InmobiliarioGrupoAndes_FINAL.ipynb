# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanGallo132/sprint11-final-proyecto-10-Inmobiliaria-An-lisis-de-Ventas-2023-2024/blob/main/S11_Estudiante_Proyecto_InmobiliarioGrupoAndes_FINAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hola &#x1F600;,
#
# Soy **Hesus Garcia** – **"Soy el único Hesus que conoces (y probablemente conocerás) 🌟"** – Sí, como "Jesús", pero con una H que me hace único. Puede sonar raro, pero créeme, ¡no lo olvidarás! Como tu revisor en Triple-Ten, estoy aquí para guiarte y ayudarte a mejorar tu código. Si algo necesita un ajuste, no hay de qué preocuparse; ¡aquí estoy para hacer que tu trabajo brille con todo su potencial! ✨
#
# Cada vez que encuentre un detalle importante en tu código, te lo señalaré para que puedas corregirlo y así te prepares para un ambiente de trabajo real, donde el líder de tu equipo actuaría de manera similar. Si en algún momento no logras solucionar el problema, te daré más detalles para ayudarte en nuestra próxima oportunidad de revisión.
#
# Es importante que cuando encuentres un comentario, **no los muevas, no los modifiques, ni los borres**.
#
# ---
#
# ### Formato de Comentarios
#
# Revisaré cuidadosamente cada implementación en tu notebook para asegurar que cumpla con los requisitos y te daré comentarios de acuerdo al siguiente formato:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> - ¡Excelente trabajo! Esta parte está bien implementada y contribuye significativamente al análisis de datos o al proyecto. Continúa aplicando estas buenas prácticas en futuras secciones.
#
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Atención</b> ⚠️ - Este código está correcto, pero se puede optimizar. Considera implementar mejoras para que sea más eficiente y fácil de leer. Esto fortalecerá la calidad de tu proyecto.
#
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>A resolver</b> ❗ - Aquí hay un problema o error en el código que es necesario corregir para aprobar esta sección. Por favor, revisa y corrige este punto, ya que es fundamental para la validez del análisis y la precisión de los resultados.
#
# </div>
#
# ---
#
# Al final de cada revisión, recibirás un **Comentario General del Revisor** que incluirá:
#
# - **Aspectos positivos:** Un resumen de los puntos fuertes de tu proyecto.
# - **Áreas de mejora:** Sugerencias sobre aspectos donde puedes mejorar.
# - **Temas adicionales para investigar:** Ideas de temas opcionales que puedes explorar por tu cuenta para desarrollar aún más tus habilidades.
#
# Estos temas adicionales no son obligatorios en esta etapa, pero pueden serte útiles para profundizar en el futuro.
#
# ---
#
#
# Esta estructura en viñetas facilita la lectura y comprensión de cada parte del comentario final.
#
# También puedes responderme de la siguiente manera si tienes alguna duda o quieres aclarar algo específico:
#
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Aquí puedes escribir tu respuesta o pregunta sobre el comentario.
#
# </div>
#
#
# **¡Empecemos!** &#x1F680;

# %% [markdown]
# # 📊 Proyecto: Análisis Comercial Inmobiliario
#
# El sector inmobiliario necesita evaluar su **desempeño comercial** para comprender su crecimiento, rentabilidad y comportamiento de clientes.
#
# Se solicita construir un **dashboard ejecutivo** que permita analizar ventas, clientes y propiedades para apoyar decisiones estratégicas basadas en datos.

# %% [markdown]
# # 📂 Descripción de los Datasets
#
# 🔹 **hecho_ventas_propiedades**
# Tabla de hechos con las transacciones de venta (precio, cliente, propiedad, canal, fecha).
#
# 🔹 **dim_clientes**
# Información y segmentación de clientes.
#
# 🔹 **dim_propiedades**
# Características de las propiedades (tipo, tamaño, ubicación, etc).
#
# 🔹 **dim_fecha**
# Tabla calendario que deberá ser creada como parte del modelado.

# %% [markdown]
# # 🎯 Preguntas que el dashboard debe responder
#
# **Desempeño general**
#
# - ¿Cuál es el **ingreso total** generado por la empresa?
# - ¿Cuántas **propiedades se han vendido**?
# - ¿Cuál es el **precio promedio de venta**?
# - ¿Cuál es la **comisión total** generada por la empresa?
#
# **Análisis comercial**
#
# - ¿Qué **tipo de propiedad genera más ingresos**?
# - ¿Qué **segmento de clientes compra más propiedades**?
# - ¿Qué canal de venta **genera mayor ingresos**?
#
#
# **Análisis temporal**
#
# - ¿Cómo evolucionan las **ventas en el tiempo**?
# - ¿El negocio está **creciendo año contra año**?
# - ¿Cómo va el desempeño **acumulado del año actual (YTD)**?
#
# **Cohortes de clientes**
#
# - ¿Los clientes **vuelven a comprar** después de su primera compra?
# - ¿Qué **cohortes de clientes generan más compras/ingresos con el tiempo**?

# %% [markdown]
# ## 🧹 Paso 1: Limpieza de datos
#
# Antes del modelado, debes validar y depurar la información.
#
# ### Tipos de datos
#
# - `fecha_venta` debe estar en formato **Date**.
# - Los campos numéricos deben estar correctamente formateados.
# - `porcentaje_comision` debe estar en formato **porcentaje**.
#
# ### Valores nulos
#
# - Revisar valores **nulos** en las tablas.
# - Justificar si deben eliminarse o mantenerse.
#
# ### Duplicados
#
# - Validar que no existan duplicados en las claves primarias de:
#   - `dim_clientes`
#   - `dim_propiedades`

# %% [markdown]
# ### Anotaciones
#
# 1. Se realiza la verificación de formatos de todas las columnas.
# 2. Se realiza la transformación de la columna 'porcentaje_comision' a la columna 'porcentaje_comision_decimal' con la fórmula "porcentaje_comision / 10000" para estandarizar a números decimales y que coincida con el ejemplo suministrado en el proyecto. Además, a esta  nueva columna se le da el formato de porcentaje.
# 3. Se realiza el correcto cálculo del monto de la comisión basado en esta nueva columna. Es decir, mediante la fórmula "precio_venta * porcentaje_comision_decimal" se obtiene la columan 'monto_comision_calculado'. En este cálculo se visualizan discrepancias con la columna dada predefinida en el proyecto, pero el margen de error es mínimo en la mayoría de los casos. Mientras que hay casos que por el porcentaje de la comisión calculada se ve una discrepancia mayor (tener en cuenta casos donde el porcentaje es, por ejemplo, del 0.38% por lo cual el monto de la comisión es bajo de por sí y, por supuesto, se visualiza la diferencia con la columna dada en el proyecto en sí).
# 4. Se verifican valores nulos en todas las columnas de las tres tablas dadas y NO se encuentran valores nulos.
# 5. Se verifican valores duplicados en las llaves primarias (id_cliente - id_propiedad) y NO se encuentran registros duplicados.

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios en caso de ser necesario._

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Atención</b> ⚠️ - Excelente trabajo documentando el proceso de limpieza de datos, especialmente en la validación de tipos, nulos y duplicados. Esto demuestra un buen entendimiento de la importancia de la calidad de datos en el análisis.
#
# Sin embargo, hay una mejora importante que podrías considerar: mencionas discrepancias entre la columna original de comisión y la calculada, pero no queda completamente claro cuál de las dos se utiliza finalmente en el modelo y dashboard. Sería ideal explicitar esta decisión y justificar cuál versión es la fuente de verdad.
#
# Esto fortalecerá la trazabilidad y confiabilidad de tu análisis. ¡Vas muy bien, este nivel de detalle ya es bastante sólido!
#
# </div>

# %% [markdown]
# ## 📅 Paso 2: Creación de tabla calendario
#
# Si vas a realizar el dashboard en **Power BI**, deberás crear una tabla calendario llamada **dim_fecha**.
#
# **Requisitos (solo para Power BI):**
#
# - Utilizar las funciones `CALENDAR` y `ADDCOLUMNS`.
# - El rango de fechas debe construirse dinámicamente desde la **fecha mínima** hasta la **fecha máxima** de ventas en `hecho_ventas_propiedades`.
# - Incluir como mínimo las siguientes columnas:
#   - Año
#   - Mes (nombre)
#   - Número de mes
#   - Año-Mes (formato `YYYY-MM`)
#
# > ⚠️ **Nota:**
# > Si utilizas **Tableau**, no necesitas crear esta tabla. Puedes usar directamente el campo `fecha_venta` de la tabla `hecho_ventas_propiedades`, ya que Tableau genera automáticamente las jerarquías de fecha.

# %% [markdown]
# ### Anotaciones
#
# 1. Se realiza la creación de una nueva tabla dim_fecha con los siguientes parámetros:</br>
#    dim_fecha = </br>
# ADDCOLUMNS(</br>
#     CALENDAR( MIN(hecho_ventas_propiedades[fecha_venta]), MAX(hecho_ventas_propiedades[fecha_venta]) ),</br>
#     "Año", YEAR([Date]),</br>
#     "Mes", FORMAT([Date], "MMMM"),</br>
#     "Mes Numero", MONTH([Date]),</br>
#     "Año-Mes", FORMAT([Date], "YYYY-MM")</br>
# )</br>
# Cumpliendo así con las condiciones establecidas para el proyecto.

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios en caso de ser necesario._

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> - ¡Excelente trabajo! La tabla calendario fue correctamente construida utilizando CALENDAR y ADDCOLUMNS, cumpliendo con el rango dinámico y las columnas requeridas. Esto es clave para habilitar análisis temporales robustos como YTD y YoY.
#
# Continúa aplicando estas buenas prácticas en futuras secciones.
#
# </div>

# %% [markdown]
# ## 🧩 Paso 3: Modelado de datos
#
# ### Modelo requerido: Esquema estrella
#
# El modelo debe estructurarse en formato estrella:
#
# - `hecho_ventas_propiedades` como tabla central.
# - Tablas dimensionales conectadas:
#   - `dim_clientes`
#   - `dim_propiedades`
#   - `dim_fecha` (creada por ti, en caso de que aplique)
#
# Requisitos de las relaciones:
#
# - Cardinalidad **uno a muchos (1:*)**
# - Dirección de filtro **simple (single)**
# - Relaciones basadas en las claves correctas
# - Todas las relaciones deben estar **activas**

# %% [markdown]
# ### Anotaciones
#
# 1. Se realiza la verificación del modelo estrella automático entre las tablas dimensión y la tabla hechos del proyecto.
# 2. Se realiza la conexión de la tabla creada dim_fecha y la tabla hechos mediante la llave primaria de fecha.
# 3. Se ajusta el modelo a nivel visual para crear la estrella.
# 4. Se verifican nuevamente las relaciones 1:* en las relaciones.

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios en caso de ser necesario._

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> - ¡Muy buen trabajo! El modelo de datos está correctamente estructurado en formato estrella, lo cual es una decisión adecuada para este tipo de análisis y facilita tanto el rendimiento como la escalabilidad del dashboard.
#
# Se evidencia un buen entendimiento al conectar la tabla de hechos con las dimensiones clave (clientes, propiedades y fecha), lo que permite habilitar análisis por múltiples perspectivas del negocio (segmento, tipo de propiedad, temporalidad). Además, la integración de la tabla calendario fue bien ejecutada y es clave para soportar métricas de inteligencia de tiempo.
#
# También es positivo que hayas validado la cardinalidad 1:* en las relaciones, ya que esto asegura consistencia en las agregaciones y evita duplicidades en los cálculos.
#
# En general, el modelo soporta correctamente las necesidades analíticas del proyecto y está bien alineado con las mejores prácticas de BI. ¡Sigue así, vas construyendo una base muy sólida!
#
# </div>

# %% [markdown]
# ## 📊 Paso 4: Creación de medidas
#
# En este paso deberás crear las **medidas necesarias para responder las preguntas de negocio del dashboard**.
#
# Las medidas pueden implementarse en **Power BI (DAX)** o como **Calculated Fields en Tableau**.
#
# ---
#
# ### 4.1 🔹 Medidas base
#
# Crear como mínimo las siguientes medidas:
#
# - **Ingreso Total** (suma del `precio_venta`)
# - **Cantidad de Ventas**
# - **Ticket Promedio**
# - **Comisión Total**
#
# Estas métricas permitirán analizar el desempeño general del negocio.
#
# ---
#
# ### 4.2 🔹 Medidas con contexto de filtro
#
# Debes crear **al menos 2 medidas** que modifiquen el contexto de filtro.
#
# En este caso se utilizarán **medidas de participación (%)**, que permiten entender **qué proporción del ingreso total aporta cada categoría**.
#
# Las medidas que deben construirse son:
#
# - **Participación de ingresos por tipo de propiedad**
# - **Participación de ingresos por canal de venta**
# - **Participación de ingresos por segmento de cliente**
#
# Para ello:
# - Modifica el contexto de filtro con las funciones propias de cada herramienta
#   - En Power BI, usa `CALCULATE`
#   - En Tableau, usa expresiones como `FIXED` (LOD)
#
# Elimina el filtro de la dimensión correspondiente para obtener el total
#
# Asegúrate de que el denominador represente el total sin el filtro de la categoría, mientras que el numerador sí lo conserva.
#
# Estas medidas se utilizarán principalmente como **tooltip o etiqueta adicional en los gráficos** del dashboard para complementar el análisis.
#
# ---
#
# ### 4.3 🔹 Inteligencia de tiempo
#
# Utilizando la tabla **`dim_fecha`** (Power BI) o las funciones de fecha en Tableau, debes crear al menos 2 de las siguientes medidas:
#
# - **Ventas Year to Date (YTD)**
# - **Ventas Month to Date (MTD)**
# - **Ventas del año anterior**
# - **Crecimiento Year over Year (YoY)**
#
# Estas métricas permitirán analizar la evolución del negocio en el tiempo.
#
# ---
#
# ### 4.4 🔹 Medidas para análisis de cohortes
#
# Debes crear cálculos que permitan analizar **si los clientes vuelven a comprar después de su primera compra**.
#
# ⚠️ Estos cálculos deben crearse como **columnas calculadas**, no como medidas.
# Todas deben crearse en la tabla **`hecho_ventas_propiedades`**.
#
# Debes crear como mínimo:
#
# - **Primera compra por cliente** → fecha mínima de compra de cada cliente.
# - **Mes Cohorte** → mes en que el cliente realizó su **primera compra** (mes de adquisición).
# - **Mes Venta** → mes en que ocurre cada transacción. Este campo permite identificar **cuándo el cliente vuelve a comprar** después de su primera compra.
#
# Estos cálculos permitirán construir una **matriz de cohortes** donde:
#
# - **Filas** representen el **mes de cohorte**
# - **Columnas** representen el **mes de venta**
# - **Valores** muestren **cantidad de ventas o ingresos**
#
# ---

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios en caso de ser necesario._

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> - ¡Excelente trabajo! Se evidencia una implementación completa y bien estructurada de las medidas requeridas para el análisis. Las métricas base están correctamente definidas y permiten analizar el desempeño general del negocio de manera clara.
#
# Además, la inclusión de medidas de participación por distintas dimensiones demuestra un buen manejo del contexto de filtro y aporta profundidad al análisis comercial. Destaca también el uso de métricas de inteligencia de tiempo como MTD, YTD y crecimiento interanual, lo cual eleva significativamente el nivel del dashboard.
#
# Finalmente, la implementación de cálculos para análisis de cohortes refleja un entendimiento avanzado del comportamiento de clientes y añade un gran valor analítico al proyecto.
#
# Continúa así, estás trabajando a un nivel muy sólido en modelado analítico.
#
# </div>

# %% [markdown]
# ## 📊 Paso 5: Estructura del reporte
#
# El dashboard debe contener **mínimo tres páginas**.
#
# ---
#
# ### 5.1 1️⃣ Overview Ejecutivo
#
# Debe mostrar **el desempeño general del negocio**.
#
# Incluir minimo 4 KPIs:
#
# - **KPIs principales**
#   - Ingreso Total
#   - Cantidad de Ventas
#   - Ticket Promedio
#   - Comisión Total
#
# - **Tendencia de ventas en el tiempo**
#
# - **Ingresos o ventas por ciudad**
#
# - **Crecimiento Year over Year (YoY)**
#
# ---
#
# ### 5.2 2️⃣ Análisis Comercial
#
# Debe analizar **qué productos, canales y clientes generan más ingresos**.
#
# Incluir:
#
# - **Ingreso por tipo de propiedad**
# - **Ventas o ingresos por canal de venta**
# - **Ventas o ingresos por segmento de cliente**
# - **Tabla con formato condicional (colores semáforo)**
#   Sugerencia de campos:
#   - tipo_propiedad
#   - Ingreso Total
#   - Cantidad Ventas
#   - Ticket Promedio
#   Aplicar **formato condicional** para resaltar las categorías con mayor desempeño.
#
# Se recomienda usar **tooltips con medidas de participación (%)**.
#
# ---
#
# ### 5.3 3️⃣ Análisis de Cohortes
#
# Debe analizar **recurrencia de clientes**.
#
# Incluir:
#
# - **Matriz de cohortes**
#   - Filas → Mes Cohorte
#   - Columnas → Mes Venta
#   - Valores → Cantidad Ventas o Ingreso Total
#
# Esto permitirá observar **si los clientes vuelven a comprar y comparar cohortes en el tiempo**.

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# Éxito - Excelente trabajo La construcción del análisis de cohortes está bien fundamentada, comenzando por la correcta identificación de la primera compra por cliente y la generación de las variables necesarias como mes de cohorte y mes de venta.
#
# Esto demuestra un entendimiento sólido del comportamiento temporal de los clientes y permite analizar la retención y recurrencia a lo largo del tiempo. La preparación de estos elementos es clave para construir una matriz de cohortes funcional y aporta un nivel avanzado de análisis al proyecto.
#
# La inclusión de este tipo de análisis va más allá de lo básico y agrega un valor significativo desde una perspectiva estratégica.
#
# Continúa así, estás incorporando técnicas analíticas de nivel avanzado.

# %% [markdown]
# ## 📝Paso 6:  Resumen Ejecutivo
#
# Escribe aquí un resumen con:
#
# - hallazgos clave
# - métricas principales
# - insights accionables
# - recomendaciones estratégicas
#
# **Hallazgos clave**
# * Ingreso Total y Volumen: El periodo cerró con un ingreso total de $6.012,50 millones generado por 8.500 ventas acumuladas
# * Liderazgo por Producto: El tipo de propiedad que genera el mayor revenue es la Casa, aportando $2.240,53 millones al ingreso total
# * Dominio Geográfico: La ciudad con mayor volumen de ventas es Ciudad de México, liderando en todos los segmentos de clientes frente a Bogotá
# * Eficiencia de Canales: El canal de venta más eficiente en términos de ingresos es el Canal Corredor, el cual genera más del triple de ingresos que el canal directo
#
# **Métricas principales Consolidad 2024**
# * Ingreso Total: $3.160 millones (+11,14% vs 2023)
# * Cantidad de Ventas: 4.455 transacciones (+10,14 % vs 2023)
# * Ticket Promedio: $710.390 (+0,91 % vs 2023)
# * Comisión Total: $95,53 millones (+10,63 % vs 2023)
#
# **Insights accionables**
# * Concentración de Segmentos: El segmento de clientes Primera vez concentra la mayor parte del ingreso y volumen de transacciones en ambas ciudades
# * Recurrencia por Cohortes: Los clientes adquiridos en las cohortes del tercer trimestre de 2024 (Q3), específicamente en agosto, muestran la mayor aceleración y crecimiento YoY, alcanzando picos de hasta 78,38% en el segmento inversionista
# * Crecimiento Interanual: Las ventas muestran un crecimiento sostenido del 11,14% YoY, respetando la estacionalidad histórica con picos de cierre trimestrales
#
# **Recomendaciones estratégicas**
# * Priorizar la comercialización de propiedades tipo Casa y Comercial, ya que presentan el ticket promedio más alto y lideran la facturación total
# * Fortalecer el canal de ventas Corredor, dado que presenta la mayor participación en el revenue y una efectividad superior en productos de alto valor
# + Implementar estrategias de retención enfocadas en convertir al segmento "Primera vez" en "Inversionista", aprovechando la aceleración de recompra observada en el segundo semestre de 2024

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios._

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Atención</b> ⚠️ - Muy buen trabajo en la redacción del resumen ejecutivo; los hallazgos, métricas e insights están bien estructurados y comunican claramente el desempeño del negocio.
#
# Como detalle a mejorar, parece que algunos caracteres especiales (como el símbolo "$" o ciertos formatos numéricos) están siendo interpretados como LaTeX dentro del notebook, lo que genera que el texto se visualice de forma incorrecta. Te recomiendo revisar el uso de estos símbolos o escaparlos adecuadamente para asegurar una correcta visualización.
#
# Ajustar este punto mejorará la presentación final de tu análisis. ¡Vas muy bien, solo es un detalle de formato!
#
# </div>

# %% [markdown]
# ## 🚀 Entrega Final
#
# Comparte el acceso a tu proyecto final para revisión.
#
# Puedes entregar el proyecto utilizando **Power BI o Tableau**.
#
# Incluye **uno de los siguientes**:
#
# - 🔗 Link público del dashboard publicado en **Power BI Service o Tableau Public / Tableau Cloud**
# - 🔗 Link de **Google Drive o OneDrive** con el archivo `.pbix` del proyecto
# - ✅ Confirmación de que el archivo `.pbix` fue subido según las instrucciones del curso
#
# ### 📎 Enlace del proyecto
# ✏️ (Pega aquí tu link o escribe "Subi mi proyecto a la plataforma")

# %% [markdown]
# # Link para visualizar el dashboard
# https://app.powerbi.com/groups/me/reports/0c27a47e-71d0-4436-8f82-f77182e0f199/0b7acadc2e7bee2ee692?experience=power-bi
#
# <div class="alert alert-block alert-warning">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Atención</b> ⚠️ - Buen trabajo completando el desarrollo del dashboard y compartiendo el enlace del proyecto. Sin embargo, el link proporcionado corresponde a una ruta interna de Power BI (por ejemplo, contiene "/groups/me/reports/..."), lo que significa que no es un enlace público accesible para revisión externa.
#
# Para que el dashboard pueda ser evaluado correctamente, es necesario generar un enlace público utilizando la opción "Publish to web" en Power BI Service. Los enlaces públicos válidos suelen tener un formato como:
#
# https://app.powerbi.com/view?r=...
#
# Te recomiendo verificar el enlace abriéndolo en una ventana de incógnito antes de entregarlo. Esto asegurará que cualquier usuario pueda acceder sin necesidad de iniciar sesión.
#
# Corregir este punto permitirá completar exitosamente la revisión del proyecto. ¡Vas muy bien, solo falta este último ajuste!
#
# </div>
#
# # Link proyecto en github
# https://github.com/JuanGallo132/sprint11-final-proyecto-10-Inmobiliaria-An-lisis-de-Ventas-2023-2024

# %% [markdown]
# # Comentario Final del Revisor

# %%
from IPython.display import HTML, display

display(HTML("<div style='background:#FFFBEB;border:4px solid #000;border-radius:24px;box-shadow:12px 12px 0 #000;padding:28px 32px;font-family:\"Inter\",ui-sans-serif,system-ui,-apple-system,sans-serif;color:#000;max-width:1000px;margin:20px auto;'><div style='display:flex;align-items:center;justify-content:space-between;gap:20px;flex-wrap:wrap;margin-bottom:28px;'><div style='font-weight:900;font-size:28px;line-height:1.1;letter-spacing:-0.5px;'>Análisis Comercial Inmobiliario</div><div style='font-weight:900;font-size:16px;background:#A7F3D0;border:4px solid #000;border-radius:999px;padding:10px 20px;box-shadow:6px 6px 0 #000;transform:rotate(-2deg);'>APROBADO ✓</div></div><div style='background:#FEF08A;border:4px solid #000;border-radius:16px;padding:20px 24px;box-shadow:8px 8px 0 #000;margin-bottom:24px;'><div style='font-weight:900;font-size:13px;text-transform:uppercase;letter-spacing:1px;margin-bottom:8px;color:#666;'>Resumen</div><div style='font-weight:600;font-size:17px;line-height:1.5;'>Informe claro y bien estructurado. Se entiende el enfoque del análisis, las métricas clave y los principales hallazgos del negocio.</div></div><div style='background:#FFF;border:4px solid #000;border-radius:16px;padding:20px 24px;box-shadow:6px 6px 0 #000;margin-bottom:20px;'><div style='display:flex;align-items:center;gap:12px;margin-bottom:14px;'><div style='background:#86EFAC;width:12px;height:12px;border:3px solid #000;border-radius:4px;'></div><div style='font-weight:900;font-size:18px;'>Lo que está bien</div></div><ul style='margin:0;padding-left:24px;font-weight:500;line-height:1.7;font-size:15px;'><li>Estructura clara y fácil de seguir.</li><li>Buen manejo de KPIs y métricas de negocio.</li><li>Uso sólido de análisis temporal (YTD, YoY).</li><li>Incorporación de análisis de cohortes.</li></ul></div><div style='display:grid;grid-template-columns:1fr 1fr;gap:20px;margin-bottom:20px;'><div style='background:#FFF;border:4px solid #000;border-radius:16px;padding:20px 24px;box-shadow:6px 6px 0 #000;'><div style='display:flex;align-items:center;gap:12px;margin-bottom:14px;'><div style='background:#FCD34D;width:12px;height:12px;border:3px solid #000;border-radius:4px;transform:rotate(45deg);'></div><div style='font-weight:900;font-size:18px;'>Mejoras recomendadas</div></div><ul style='margin:0;padding-left:24px;font-weight:500;line-height:1.7;font-size:14px;'><li>Validar que el link del dashboard sea público (Publish to web).</li><li>Documentar brevemente las medidas clave (DAX).</li></ul></div><div style='background:#FFF;border:4px solid #000;border-radius:16px;padding:20px 24px;box-shadow:6px 6px 0 #000;'><div style='display:flex;align-items:center;gap:12px;margin-bottom:14px;'><div style='background:#C4B5FD;width:12px;height:12px;border:3px solid #000;border-radius:50%;'></div><div style='font-weight:900;font-size:18px;'>Lecturas recomendadas</div></div><ul style='margin:0;padding-left:24px;font-weight:500;line-height:1.7;font-size:14px;'><li>Storytelling with Data (Cole Nussbaumer Knaflic).</li></ul><div style='margin-top:16px;padding-top:14px;border-top:3px dashed #000;'><div style='font-weight:700;font-size:13px;line-height:1.5;background:#E0E7FF;padding:10px 14px;border-radius:8px;border:2px solid #000;'>💡 Practica resumir tus análisis en 3–4 insights accionables claros.</div></div></div></div><div style='background:#F9A8D4;border:4px solid #000;border-radius:20px;padding:24px 28px;box-shadow:8px 8px 0 #000;margin-bottom:20px;position:relative;'><div style='position:absolute;top:-14px;right:24px;background:#FFF;border:3px solid #000;border-radius:999px;padding:6px 14px;font-weight:900;font-size:12px;box-shadow:4px 4px 0 #000;transform:rotate(3deg);'>🎉 GRAN LOGRO</div><div style='font-weight:900;font-size:22px;margin-bottom:12px;'>Felicidades por completar un dashboard</div><div style='font-weight:500;font-size:15px;line-height:1.65;'>Has logrado construir un proyecto completo de análisis de datos, desde el modelado hasta la visualización y los insights. Este es un gran paso hacia un rol profesional en data.</div></div></div>"))
# Out:
# <div style='background:#FFFBEB;border:4px solid #000;border-radius:24px;box-shadow:12px 12px 0 #000;padding:28px 32px;font-family:"Inter",ui-sans-serif,system-ui,-apple-system,sans-serif;color:#000;max-width:1000px;margin:20px auto;'><div style='display:flex;align-items:center;justify-content:space-between;gap:20px;flex-wrap:wrap;margin-bottom:28px;'><div style='font-weight:900;font-size:28px;line-height:1.1;letter-spacing:-0.5px;'>Análisis Comercial Inmobiliario</div><div style='font-weight:900;font-size:16px;background:#A7F3D0;border:4px solid #000;border-radius:999px;padding:10px 20px;box-shadow:6px 6px 0 #000;transform:rotate(-2deg);'>APROBADO ✓</div></div><div style='background:#FEF08A;border:4px solid #000;border-radius:16px;padding:20px 24px;box-shadow:8px 8px 0 #000;margin-bottom:24px;'><div style='font-weight:900;font-size:13px;text-transform:uppercase;letter-spacing:1px;margin-bottom:8px;color:#666;'>Resumen</div><div style='font-weight:600;font-size:17px;line-height:1.5;'>
# ...
